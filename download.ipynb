# %% [markdown]
#  # Downloading the data

# %% [markdown]
# First, a data directory is created on your local computer. Then, download parameters for each data source are defined, including the URL. These parameters are then turned into a YAML-string. Finally, the download is executed one by one. If all data need to be downloaded, this usually takes several hours.

# %% [markdown]
# # Table of Contents
# * [1. Settings](#1.-Settings)
# 	* [1.1 Libraries](#1.1-Libraries)
# 	* [1.2 Creating a data directory](#1.2-Creating-a-data-directory)
# * [2. Parameters for individual data sources](#2.-Parameters-for-individual-data-sources)
# 	* [2.1 ENTSO-E](#2.1-ENTSO-E)
# 	* [2.2 '50Hertz](#2.2-'50Hertz)
# 	* [2.3 Amprion](#2.3-Amprion)
# 	* [2.4 TransnetBW](#2.4-TransnetBW)
# 	* [2.5 TenneT](#2.5-TenneT)
# 	* [2.6 Creating YAML strings](#2.6-Creating-YAML-strings)
# * [3. Downloading files one by one](#3.-Downloading-files-one-by-one)

# %% [markdown]
# # 1. Settings

# %% [markdown]
# ## 1.1 Libraries

# %% [markdown]
# Loading some python libraries.

# %%
from datetime import datetime , date
import yaml
import requests
import os
import pandas as pd
import logging

# %% [markdown]
# Set up a log.

# %%
logger = logging.getLogger('log')
logger.setLevel('INFO')

# %% [markdown]
# ## 1.2 Creating a data directory

# %% [markdown]
# This section creates a folder "downloadpath" inside the notebook's directory on the user's local computer for the downloaded data. The folder is labelled with a time stamp.

# %%
downloadpath = 'downloads2'
os.makedirs(downloadpath, exist_ok=True)
archivepath = os.path.join(
    downloadpath, 'archive-' + datetime.now().strftime('%Y-%m-%d')
    )

# %% [markdown]
# Do you want to save a copy of each downloaded file under the original filename? If so, Set ARCHIVE = True, if not, set ARCHIVE = False. The latter has the advantage that it's considerably faster if some files have already been downladed during a previous run, whereas the former will download every file again, because otherwise it's not possible to compare the filenames.

# %% [markdown]
# # 2. Parameters for individual data sources

# %% [markdown]
# This section contains a python dictionary for each download source with input parameters needed to generate the URLs for the data.

# %% [markdown]
# ## 2.1 ENTSO-E

# %%
entso = """
ENTSO-E: 
    Data_Portal: 
        url_template: https://www.entsoe.eu/fileadmin/template/other/statistical_database/excel.php
        url_params_template:
            pid: '136'
            opt_period: '0'
            send: send
            opt_Response: '99'
            dataindx: '0'
            opt_Month: '{u_start.month}'
            opt_Year: '{u_start.year}'
        frequency: M
        start: 2006-01-01
        end: recent
        filetype: xls
"""

# %% [markdown]
# ## 2.2 '50Hertz

# %%
hertz = """
50Hertz: 
    wind: 
        url_template: http://ws.50hertz.com/web01/api/WindPowerForecast/DownloadFile
        url_params_template:
            callback: '?'
            fileName: '{u_start:%Y}.csv'
        frequency: A
        start: 2005-01-01
        end: recent
        filetype: csv
    pv: 
        url_template: http://ws.50hertz.com/web01/api/PhotovoltaicForecast/DownloadFile
        url_params_template:
            callback: '?'
            fileName: '{u_start:%Y}.csv'
        frequency: A
        start: 2012-01-01
        end: recent
        filetype: csv
"""

# %% [markdown]
# ## 2.3 Amprion

# %%
amprion = """
Amprion:
    wind: 
        url_template: http://amprion.de/applications/applicationfiles/winddaten2.php
        url_params_template:
            mode: download
            format: csv
            start: '{u_start.day}.{u_start.month}.{u_start.year}'
            end: '{u_end.day}.{u_end.month}.{u_end.year}' # dates must not be zero-padded
        frequency: complete
        start: 2008-01-04
        end: recent
        filetype: csv
    pv: 
        url_template: http://amprion.de/applications/applicationfiles/PV_einspeisung.php
        url_params_template:
            mode: download
            format: csv
            start: '{u_start.day}.{u_start.month}.{u_start.year}'
            end: '{u_end.day}.{u_end.month}.{u_end.year}' # dates must not be zero-padded        
        frequency: complete
        start: 2010-01-07
        end: recent
        filetype: csv
"""

# %% [markdown]
# ## 2.4 TransnetBW

# %%
transnetbw = """
TransnetBW: 
    wind: 
        url_template: https://www.transnetbw.de/de/kennzahlen/erneuerbare-energien/windenergie
        url_params_template:
            app: wind
            activeTab: csv
            view: '1'
            download: 'true'
            selectMonatDownload: '{u_transnetbw}'
        frequency: M
        start: 2010-01-01
        end: recent
        filetype: csv
    pv: 
        url_template: https://www.transnetbw.de/de/kennzahlen/erneuerbare-energien/fotovoltaik
        url_params_template:
            app: wind
            activeTab: csv
            view: '1'
            download: 'true'
            selectMonatDownload: '{u_transnetbw}'
        frequency: M
        start: 2011-01-01
        end: recent
        filetype: csv
"""

# %% [markdown]
# ## 2.5 TenneT

# %%
tennet = """
TenneT: 
    wind: 
        url_template: http://www.tennettso.de/site/de/phpbridge
        url_params_template:
            commandpath: Tatsaechliche_und_prognostizierte_Windenergieeinspeisung/monthDataSheetCsv.php
            contenttype: text/x-csv
            querystring: monat={u_start:%Y-%m}
        frequency: M
        start: 2006-01-01
        end: recent
        filetype: csv        
    pv: 
        url_template: http://www.tennettso.de/site/de/phpbridge
        url_params_template:
            commandpath: Tatsaechliche_und_prognostizierte_Solarenergieeinspeisung/monthDataSheetCsv.php
            sub: total
            contenttype: text/x-csv
            querystring: monat={u_start:%Y-%m}
        frequency: M
        start: 2010-01-01
        end: recent
        filetype: csv  
"""

# %% [markdown]
# ## 2.6 Creating YAML strings

# %% [markdown]
# Loading the parameters for the data sources we wish to include into a [YAML](https://en.wikipedia.org/wiki/YAML)-string.

# %%
conf = yaml.load(hertz + amprion + tennet + transnetbw + entso)

# %% [markdown]
# # 3. Downloading files one by one

# %% [markdown]
# In the following we iterate over the sources and technology (wind/solar) entries specified above and download the data for a the period given in the parameters. Each file is  saved under it's original filename. Note that the original file names are often not self-explanatory (called "data" or "January"). The files content is revealed by its place in the directory structure.

# %%
def download(session, source, tech, s, e, **p):
    """construct URLs from template and parameters, download, and save."""
    logger.info(
        'Proceed to download: {} {} {:%Y-%m-%d}_{:%Y-%m-%d}'.format(
            source, tech, s, e
            )
        )
    # Get number of months between now and s (required for TransnetBW).
    count = datetime.now().month - s.month + (datetime.now().year - s.year)*12
    
    # Create the parameters dict containing timespan info to be pasted with url
    url_params = {}
    for key, value in p['url_params_template'].items():
        url_params[key] = value.format(
            u_start = s,
            u_end = e,
            u_transnetbw = count
            )

    # Each file will be saved in a folder of its own, this allows us to preserve
    # the original filename when saving to disk.  
    unique_path = os.path.join(
        downloadpath,
        source,
        tech,
        s.strftime('%Y-%m-%d') + '_' + e.strftime('%Y-%m-%d')
        )
    os.makedirs(unique_path, exist_ok=True)
    
    # Attempt the download if there is no file yet.  
    count_files =  len(os.listdir(unique_path))   
    if count_files == 0: 
        resp = session.get(p['url_template'], params=url_params)                
        original_filename = resp.headers['content-disposition'].split(
            'filename=')[-1].replace('"','').replace(';','')              
        logger.info(
            'Downloading from URL: %s Original filename: %s',
            resp.url, original_filename
            )
        filepath = os.path.join(unique_path, original_filename)
        with open(filepath, 'wb') as output_file:
            for chunk in resp.iter_content(1024):
                output_file.write(chunk)                
    elif count_files == 1:
        logger.info('There is already a file: %s', os.listdir(unique_path)[0])
    else:
        logger.info('There must not be more than one file in: %s. Please check ', unique_path)        
        
    return


for source, t in conf.items():
    for tech, p in t.items():
        session = requests.session()
#        p['start'] = date(2015,1,1) # uncomment this to set a different start
        if p['end'] == 'recent':
            p['end'] = date(2015,12,31)

        if p['frequency'] == 'complete':
            download(session, source, tech, p['start'], p['end'], **p)            
        else:
            # The files on the servers usually contain the data for subperiods
            # of some regular length (i.e. months or yearsavailable 
            # Create lists of start- and enddates of periods represented in
            # individual files to be downloaded.  
            starts = pd.date_range(
                start=p['start'], end=p['end'], freq=p['frequency']+'S')
            ends = pd.date_range(
                start=p['start'], end=p['end'], freq=p['frequency'])
            for start, end in zip(starts, ends):
                download(session, source, tech, start, end, **p)
# Out:
# INFO:log:Proceed to download: Amprion wind 2008-01-04_2015-12-31
# INFO:log:There is already a file: winddaten2_04.01.2008_31.12.2015.csv
# INFO:log:Proceed to download: Amprion pv 2010-01-07_2015-12-31
# INFO:log:There is already a file: Photovoltaik_07.01.2010_31.12.2015.csv
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-01-01_2006-01-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-02-01_2006-02-28
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-03-01_2006-03-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-04-01_2006-04-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-05-01_2006-05-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-06-01_2006-06-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-07-01_2006-07-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-08-01_2006-08-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-09-01_2006-09-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-10-01_2006-10-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-11-01_2006-11-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2006-12-01_2006-12-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-01-01_2007-01-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-02-01_2007-02-28
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-03-01_2007-03-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-04-01_2007-04-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-05-01_2007-05-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-06-01_2007-06-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-07-01_2007-07-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-08-01_2007-08-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-09-01_2007-09-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-10-01_2007-10-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-11-01_2007-11-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2007-12-01_2007-12-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-01-01_2008-01-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-02-01_2008-02-29
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-03-01_2008-03-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-04-01_2008-04-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-05-01_2008-05-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-06-01_2008-06-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-07-01_2008-07-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-08-01_2008-08-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-09-01_2008-09-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-10-01_2008-10-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-11-01_2008-11-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2008-12-01_2008-12-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2009-01-01_2009-01-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2009-02-01_2009-02-28
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2009-03-01_2009-03-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2009-04-01_2009-04-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2009-05-01_2009-05-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2009-06-01_2009-06-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2009-07-01_2009-07-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2009-08-01_2009-08-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2009-09-01_2009-09-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2009-10-01_2009-10-31
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2009-11-01_2009-11-30
# INFO:log:There is already a file: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 
send=send&opt_period=0&opt_Response=99 Original filename: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2015-08-01_2015-08-31
# INFO:log:Downloading from URL: https://www.entsoe.eu/fileadmin/template/other/statistical_database/excel.php?dataindx=0&pid=136&opt_Month=8&opt_Year=2015&send=send&opt_period=0&opt_Response=99 Original filename: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2015-09-01_2015-09-30
# INFO:log:Downloading from URL: https://www.entsoe.eu/fileadmin/template/other/statistical_database/excel.php?dataindx=0&pid=136&opt_Month=9&opt_Year=2015&send=send&opt_period=0&opt_Response=99 Original filename: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2015-10-01_2015-10-31
# INFO:log:Downloading from URL: https://www.entsoe.eu/fileadmin/template/other/statistical_database/excel.php?dataindx=0&pid=136&opt_Month=10&opt_Year=2015&send=send&opt_period=0&opt_Response=99 Original filename: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2015-11-01_2015-11-30
# INFO:log:Downloading from URL: https://www.entsoe.eu/fileadmin/template/other/statistical_database/excel.php?dataindx=0&pid=136&opt_Month=11&opt_Year=2015&send=send&opt_period=0&opt_Response=99 Original filename: Statistics.xls
# INFO:log:Proceed to download: ENTSO-E Data_Portal 2015-12-01_2015-12-31
# INFO:log:Downloading from URL: https://www.entsoe.eu/fileadmin/template/other/statistical_database/excel.php?dataindx=0&pid=136&opt_Month=12&opt_Year=2015&send=send&opt_period=0&opt_Response=99 Original filename: Statistics.xls
# INFO:log:Proceed to download: 50Hertz wind 2005-01-01_2005-12-31
# INFO:log:There is already a file: 2005.csv
# INFO:log:Proceed to download: 50Hertz wind 2006-01-01_2006-12-31
# INFO:log:There is already a file: 2006.csv
# INFO:log:Proceed to download: 50Hertz wind 2007-01-01_2007-12-31
# INFO:log:There is already a file: 2007.csv
# INFO:log:Proceed to download: 50Hertz wind 2008-01-01_2008-12-31
# INFO:log:There is already a file: 2008.csv
# INFO:log:Proceed to download: 50Hertz wind 2009-01-01_2009-12-31
# INFO:log:There is already a file: 2009.csv
# INFO:log:Proceed to download: 50Hertz wind 2010-01-01_2010-12-31
# INFO:log:There is already a file: 2010.csv
# INFO:log:Proceed to download: 50Hertz wind 2011-01-01_2011-12-31
# INFO:log:There is already a file: 2011.csv
# INFO:log:Proceed to download: 50Hertz wind 2012-01-01_2012-12-31
# INFO:log:There is already a file: 2012.csv
# INFO:log:Proceed to download: 50Hertz wind 2013-01-01_2013-12-31
# INFO:log:There is already a file: 2013.csv
# INFO:log:Proceed to download: 50Hertz wind 2014-01-01_2014-12-31
# INFO:log:There is already a file: 2014.csv
# INFO:log:Proceed to download: 50Hertz wind 2015-01-01_2015-12-31
# INFO:log:There is already a file: 2015.csv
# INFO:log:Proceed to download: 50Hertz pv 2012-01-01_2012-12-31
# INFO:log:There is already a file: 2012.csv
# INFO:log:Proceed to download: 50Hertz pv 2013-01-01_2013-12-31
# INFO:log:There is already a file: 2013.csv
# INFO:log:Proceed to download: 50Hertz pv 2014-01-01_2014-12-31
# INFO:log:There is already a file: 2014.csv
# INFO:log:Proceed to download: 50Hertz pv 2015-01-01_2015-12-31
# INFO:log:There is already a file: 2015.csv
# INFO:log:Proceed to download: TenneT wind 2006-01-01_2006-01-31
# INFO:log:There is already a file: Export_Januar-2006.csv
# INFO:log:Proceed to download: TenneT wind 2006-02-01_2006-02-28
# INFO:log:There is already a file: Export_Februar-2006.csv
# INFO:log:Proceed to download: TenneT wind 2006-03-01_2006-03-31
# INFO:log:There is already a file: Export_Maerz-2006.csv
# INFO:log:Proceed to download: TenneT wind 2006-04-01_2006-04-30
# INFO:log:There is already a file: Export_April-2006.csv
# INFO:log:Proceed to download: TenneT wind 2006-05-01_2006-05-31
# INFO:log:There is already a file: Export_Mai-2006.csv
# INFO:log:Proceed to download: TenneT wind 2006-06-01_2006-06-30
# INFO:log:There is already a file: Export_Juni-2006.csv
# INFO:log:Proceed to download: TenneT wind 2006-07-01_2006-07-31
# INFO:log:There is already a file: Export_Juli-2006.csv
# INFO:log:Proceed to download: TenneT wind 2006-08-01_2006-08-31
# INFO:log:There is already a file: Export_August-2006.csv
# INFO:log:Proceed to download: TenneT wind 2006-09-01_2006-09-30
# INFO:log:There is already a file: Export_September-2006.csv
# INFO:log:Proceed to download: TenneT wind 2006-10-01_2006-10-31
# INFO:log:There is already a file: Export_Oktober-2006.csv
# INFO:log:Proceed to download: TenneT wind 2006-11-01_2006-11-30
# INFO:log:There is already a file: Export_November-2006.csv
# INFO:log:Proceed to download: TenneT wind 2006-12-01_2006-12-31
# INFO:log:There is already a file: Export_Dezember-2006.csv
# INFO:log:Proceed to download: TenneT wind 2007-01-01_2007-01-31
# INFO:log:There is already a file: Export_Januar-2007.csv
# INFO:log:Proceed to download: TenneT wind 2007-02-01_2007-02-28
# INFO:log:There is already a file: Export_Februar-2007.csv
# INFO:log:Proceed to download: TenneT wind 2007-03-01_2007-03-31
# INFO:log:There is already a file: Export_Maerz-2007.csv
# INFO:log:Proceed to download: TenneT wind 2007-04-01_2007-04-30
# INFO:log:There is already a file: Export_April-2007.csv
# INFO:log:Proceed to download: TenneT wind 2007-05-01_2007-05-31
# INFO:log:There is already a file: Export_Mai-2007.csv
# INFO:log:Proceed to download: TenneT wind 2007-06-01_2007-06-30
# INFO:log:There is already a file: Export_Juni-2007.csv
# INFO:log:Proceed to download: TenneT wind 2007-07-01_2007-07-31
# INFO:log:There is already a file: Export_Juli-2007.csv
# INFO:log:Proceed to download: TenneT wind 2007-08-01_2007-08-31
# INFO:log:There is already a file: Export_August-2007.csv
# INFO:log:Proceed to download: TenneT wind 2007-09-01_2007-09-30
# INFO:log:There is already a file: Export_September-2007.csv
# INFO:log:Proceed to download: TenneT wind 2007-10-01_2007-10-31
# INFO:log:There is already a file: Export_Oktober-2007.csv
# INFO:log:Proceed to download: TenneT wind 2007-11-01_2007-11-30
# INFO:log:There is already a file: Export_November-2007.csv
# INFO:log:Proceed to download: TenneT wind 2007-12-01_2007-12-31
# INFO:log:There is already a file: Export_Dezember-2007.csv
# INFO:log:Proceed to download: TenneT wind 2008-01-01_2008-01-31
# INFO:log:There is already a file: Export_Januar-2008.csv
# INFO:log:Proceed to download: TenneT wind 2008-02-01_2008-02-29
# INFO:log:There is already a file: Export_Februar-2008.csv
# INFO:log:Proceed to download: TenneT wind 2008-03-01_2008-03-31
# INFO:log:There is already a file: Export_Maerz-2008.csv
# INFO:log:Proceed to download: TenneT wind 2008-04-01_2008-04-30
# INFO:log:There is already a file: Export_April-2008.csv
# INFO:log:Proceed to download: TenneT wind 2008-05-01_2008-05-31
# INFO:log:There is already a file: Export_Mai-2008.csv
# INFO:log:Proceed to download: TenneT wind 2008-06-01_2008-06-30
# INFO:log:There is already a file: Export_Juni-2008.csv
# INFO:log:Proceed to download: TenneT wind 2008-07-01_2008-07-31
# INFO:log:There is already a file: Export_Juli-2008.csv
# INFO:log:Proceed to download: TenneT wind 2008-08-01_2008-08-31
# INFO:log:There is already a file: Export_August-2008.csv
# INFO:log:Proceed to download: TenneT wind 2008-09-01_2008-09-30
# INFO:log:There is already a file: Export_September-2008.csv
# INFO:log:Proceed to download: TenneT wind 2008-10-01_2008-10-31
# INFO:log:There is already a file: Export_Oktober-2008.csv
# INFO:log:Proceed to download: TenneT wind 2008-11-01_2008-11-30
# INFO:log:There is already a file: Export_November-2008.csv
# INFO:log:Proceed to download: TenneT wind 2008-12-01_2008-12-31
# INFO:log:There is already a file: Export_Dezember-2008.csv
# INFO:log:Proceed to download: TenneT wind 2009-01-01_2009-01-31
# INFO:log:There is already a file: Export_Januar-2009.csv
# INFO:log:Proceed to download: TenneT wind 2009-02-01_2009-02-28
# INFO:log:There is already a file: Export_Februar-2009.csv
# INFO:log:Proceed to download: TenneT wind 2009-03-01_2009-03-31
# INFO:log:There is already a file: Export_Maerz-2009.csv
# INFO:log:Proceed to download: TenneT wind 2009-04-01_2009-04-30
# INFO:log:There is already a file: Export_April-2009.csv
# INFO:log:Proceed to download: TenneT wind 2009-05-01_2009-05-31
# INFO:log:There is already a file: Export_Mai-2009.csv
# INFO:log:Proceed to download: TenneT wind 2009-06-01_2009-06-30
# INFO:log:There is already a file: Export_Juni-2009.csv
# INFO:log:Proceed to download: TenneT wind 2009-07-01_2009-07-31
# INFO:log:There is already a file: Export_Juli-2009.csv
# INFO:log:Proceed to download: TenneT wind 2009-08-01_2009-08-31
# INFO:log:There is already a file: Export_August-2009.csv
# INFO:log:Proceed to download: TenneT wind 2009-09-01_2009-09-30
# INFO:log:There is already a file: Export_September-2009.csv
# INFO:log:Proceed to download: TenneT wind 2009-10-01_2009-10-31
# INFO:log:There is already a file: Export_Oktober-2009.csv
# INFO:log:Proceed to download: TenneT wind 2009-11-01_2009-11-30
# INFO:log:There is already a file: Export_November-2009.csv
# INFO:log:Proceed to download: TenneT wind 2009-12-01_2009-12-31
# INFO:log:There is already a file: Export_Dezember-2009.csv
# INFO:log:Proceed to download: TenneT wind 2010-01-01_2010-01-31
# INFO:log:There is already a file: Export_Januar-2010.csv
# INFO:log:Proceed to download: TenneT wind 2010-02-01_2010-02-28
# INFO:log:There is already a file: Export_Februar-2010.csv
# INFO:log:Proceed to download: TenneT wind 2010-03-01_2010-03-31
# INFO:log:There is already a file: Export_Maerz-2010.csv
# INFO:log:Proceed to download: TenneT wind 2010-04-01_2010-04-30
# INFO:log:There is already a file: Export_April-2010.csv
# INFO:log:Proceed to download: TenneT wind 2010-05-01_2010-05-31
# INFO:log:There is already a file: Export_Mai-2010.csv
# INFO:log:Proceed to download: TenneT wind 2010-06-01_2010-06-30
# INFO:log:There is already a file: Export_Juni-2010.csv
# INFO:log:Proceed to download: TenneT wind 2010-07-01_2010-07-31
# INFO:log:There is already a file: Export_Juli-2010.csv
# INFO:log:Proceed to download: TenneT wind 2010-08-01_2010-08-31
# INFO:log:There is already a file: Export_August-2010.csv
# INFO:log:Proceed to download: TenneT wind 2010-09-01_2010-09-30
# INFO:log:There is already a file: Export_September-2010.csv
# INFO:log:Proceed to download: TenneT wind 2012-11-01_2012-11-30
# INFO:log:There is already a file: Export_November-2012.csv
# INFO:log:Proceed to download: TenneT wind 2012-12-01_2012-12-31
# INFO:log:There is already a file: Export_Dezember-2012.csv
# INFO:log:Proceed to download: TenneT wind 2013-01-01_2013-01-31
# INFO:log:There is already a file: Export_Januar-2013.csv
# INFO:log:Proceed to download: TenneT wind 2013-02-01_2013-02-28
# INFO:log:There is already a file: Export_Februar-2013.csv
# INFO:log:Proceed to download: TenneT wind 2013-03-01_2013-03-31
# INFO:log:There is already a file: Export_Maerz-2013.csv
# INFO:log:Proceed to download: TenneT wind 2013-04-01_2013-04-30
# INFO:log:There is already a file: Export_April-2013.csv
# INFO:log:Proceed to download: TenneT wind 2013-05-01_2013-05-31
# INFO:log:There is already a file: Export_Mai-2013.csv
# INFO:log:Proceed to download: TenneT wind 2013-06-01_2013-06-30
# INFO:log:There is already a file: Export_Juni-2013.csv
# INFO:log:Proceed to download: TenneT wind 2013-07-01_2013-07-31
# INFO:log:There is already a file: Export_Juli-2013.csv
# INFO:log:Proceed to download: TenneT wind 2013-08-01_2013-08-31
# INFO:log:There is already a file: Export_August-2013.csv
# INFO:log:Proceed to download: TenneT wind 2013-09-01_2013-09-30
# INFO:log:There is already a file: Export_September-2013.csv
# INFO:log:Proceed to download: TenneT wind 2013-10-01_2013-10-31
# INFO:log:There is already a file: Export_Oktober-2013.csv
# INFO:log:Proceed to download: TenneT wind 2013-11-01_2013-11-30
# INFO:log:There is already a file: Export_November-2013.csv
# INFO:log:Proceed to download: TenneT wind 2013-12-01_2013-12-31
# INFO:log:There is already a file: Export_Dezember-2013.csv
# INFO:log:Proceed to download: TenneT wind 2014-01-01_2014-01-31
# INFO:log:There is already a file: Export_Januar-2014.csv
# INFO:log:Proceed to download: TenneT wind 2014-02-01_2014-02-28
# INFO:log:There is already a file: Export_Februar-2014.csv
# INFO:log:Proceed to download: TenneT wind 2014-03-01_2014-03-31
# INFO:log:There is already a file: Export_Maerz-2014.csv
# INFO:log:Proceed to download: TenneT wind 2014-04-01_2014-04-30
# INFO:log:There is already a file: Export_April-2014.csv
# INFO:log:Proceed to download: TenneT wind 2014-05-01_2014-05-31
# INFO:log:There is already a file: Export_Mai-2014.csv
# INFO:log:Proceed to download: TenneT wind 2014-06-01_2014-06-30
# INFO:log:There is already a file: Export_Juni-2014.csv
# INFO:log:Proceed to download: TenneT wind 2014-07-01_2014-07-31
# INFO:log:There is already a file: Export_Juli-2014.csv
# INFO:log:Proceed to download: TenneT wind 2014-08-01_2014-08-31
# INFO:log:There is already a file: Export_August-2014.csv
# INFO:log:Proceed to download: TenneT wind 2014-09-01_2014-09-30
# INFO:log:There is already a file: Export_September-2014.csv
# INFO:log:Proceed to download: TenneT wind 2014-10-01_2014-10-31
# INFO:log:There is already a file: Export_Oktober-2014.csv
# INFO:log:Proceed to download: TenneT wind 2014-11-01_2014-11-30
# INFO:log:There is already a file: Export_November-2014.csv
# INFO:log:Proceed to download: TenneT wind 2014-12-01_2014-12-31
# INFO:log:There is already a file: Export_Dezember-2014.csv
# INFO:log:Proceed to download: TenneT wind 2015-01-01_2015-01-31
# INFO:log:There is already a file: Export_Januar-2015.csv
# INFO:log:Proceed to download: TenneT wind 2015-02-01_2015-02-28
# INFO:log:There is already a file: Export_Februar-2015.csv
# INFO:log:Proceed to download: TenneT wind 2015-03-01_2015-03-31
# INFO:log:There is already a file: Export_Maerz-2015.csv
# INFO:log:Proceed to download: TenneT wind 2015-04-01_2015-04-30
# INFO:log:There is already a file: Export_April-2015.csv
# INFO:log:Proceed to download: TenneT wind 2015-05-01_2015-05-31
# INFO:log:There is already a file: Export_Mai-2015.csv
# INFO:log:Proceed to download: TenneT wind 2015-06-01_2015-06-30
# INFO:log:There is already a file: Export_Juni-2015.csv
# INFO:log:Proceed to download: TenneT wind 2015-07-01_2015-07-31
# INFO:log:There is already a file: Export_Juli-2015.csv
# INFO:log:Proceed to download: TenneT wind 2015-08-01_2015-08-31
# INFO:log:There is already a file: Export_August-2015.csv
# INFO:log:Proceed to download: TenneT wind 2015-09-01_2015-09-30
# INFO:log:There is already a file: Export_September-2015.csv
# INFO:log:Proceed to download: TenneT wind 2015-10-01_2015-10-31
# INFO:log:There is already a file: Export_Oktober-2015.csv
# INFO:log:Proceed to download: TenneT wind 2015-11-01_2015-11-30
# INFO:log:There is already a file: Export_November-2015.csv
# INFO:log:Proceed to download: TenneT wind 2015-12-01_2015-12-31
# INFO:log:There is already a file: Export_Dezember-2015.csv
# INFO:log:Proceed to download: TenneT pv 2010-01-01_2010-01-31
# INFO:log:There is already a file: Export_Januar-2010.csv
# INFO:log:Proceed to download: TenneT pv 2010-02-01_2010-02-28
# INFO:log:There is already a file: Export_Februar-2010.csv
# INFO:log:Proceed to download: TenneT pv 2010-03-01_2010-03-31
# INFO:log:There is already a file: Export_Maerz-2010.csv
# INFO:log:Proceed to download: TenneT pv 2010-04-01_2010-04-30
# INFO:log:There is already a file: Export_April-2010.csv
# INFO:log:Proceed to download: TenneT pv 2010-05-01_2010-05-31
# INFO:log:There is already a file: Export_Mai-2010.csv
# INFO:log:Proceed to download: TenneT pv 2010-06-01_2010-06-30
# INFO:log:There is already a file: Export_Juni-2010.csv
# INFO:log:Proceed to download: TenneT pv 2010-07-01_2010-07-31
# INFO:log:There is already a file: Export_Juli-2010.csv
# INFO:log:Proceed to download: TenneT pv 2010-08-01_2010-08-31
# INFO:log:There is already a file: Export_August-2010.csv
# INFO:log:Proceed to download: TenneT pv 2010-09-01_2010-09-30
# INFO:log:There is already a file: Export_September-2010.csv
# INFO:log:Proceed to download: TenneT pv 2010-10-01_2010-10-31
# INFO:log:There is already a file: Export_Oktober-2010.csv
# INFO:log:Proceed to download: TenneT pv 2010-11-01_2010-11-30
# INFO:log:There is already a file: Export_November-2010.csv
# INFO:log:Proceed to download: TenneT pv 2010-12-01_2010-12-31
# INFO:log:There is already a file: Export_Dezember-2010.csv
# INFO:log:Proceed to download: TenneT pv 2011-01-01_2011-01-31
# INFO:log:There is already a file: Export_Januar-2011.csv
# INFO:log:Proceed to download: TenneT pv 2011-02-01_2011-02-28
# INFO:log:There is already a file: Export_Februar-2011.csv
# INFO:log:Proceed to download: TenneT pv 2011-03-01_2011-03-31
# INFO:log:There is already a file: Export_Maerz-2011.csv
# INFO:log:Proceed to download: TenneT pv 2011-04-01_2011-04-30
# INFO:log:There is already a file: Export_April-2011.csv
# INFO:log:Proceed to download: TenneT pv 2011-05-01_2011-05-31
# INFO:log:There is already a file: Export_Mai-2011.csv
# INFO:log:Proceed to download: TenneT pv 2011-06-01_2011-06-30
# INFO:log:There is already a file: Export_Juni-2011.csv
# INFO:log:Proceed to download: TenneT pv 2011-07-01_2011-07-31
# INFO:log:There is already a file: Export_Juli-2011.csv
# INFO:log:Proceed to download: TenneT pv 2011-08-01_2011-08-31
# INFO:log:There is already a file: Export_August-2011.csv
# INFO:log:Proceed to download: TenneT pv 2011-09-01_2011-09-30
# INFO:log:There is already a file: Export_September-2011.csv
# INFO:log:Proceed to download: TenneT pv 2011-10-01_2011-10-31
# INFO:log:There is already a file: Export_Oktober-2011.csv
# INFO:log:Proceed to download: TenneT pv 2011-11-01_2011-11-30
# INFO:log:There is already a file: Export_November-2011.csv
# INFO:log:Proceed to download: TenneT pv 2011-12-01_2011-12-31
# INFO:log:There is already a file: Export_Dezember-2011.csv
# INFO:log:Proceed to download: TenneT pv 2012-01-01_2012-01-31
# INFO:log:There is already a file: Export_Januar-2012.csv
# INFO:log:Proceed to download: TenneT pv 2012-02-01_2012-02-29
# INFO:log:There is already a file: Export_Februar-2012.csv
# INFO:log:Proceed to download: TenneT pv 2012-03-01_2012-03-31
# INFO:log:There is already a file: Export_Maerz-2012.csv
# INFO:log:Proceed to download: TenneT pv 2012-04-01_2012-04-30
# INFO:log:There is already a file: Export_April-2012.csv
# INFO:log:Proceed to download: TenneT pv 2012-05-01_2012-05-31
# INFO:log:There is already a file: Export_Mai-2012.csv
# INFO:log:Proceed to download: TenneT pv 2012-06-01_2012-06-30
# INFO:log:There is already a file: Export_Juni-2012.csv
# INFO:log:Proceed to download: TenneT pv 2012-07-01_2012-07-31
# INFO:log:There is already a file: Export_Juli-2012.csv
# INFO:log:Proceed to download: TenneT pv 2012-08-01_2012-08-31
# INFO:log:There is already a file: Export_August-2012.csv
# INFO:log:Proceed to download: TenneT pv 2012-09-01_2012-09-30
# INFO:log:There is already a file: Export_September-2012.csv
# INFO:log:Proceed to download: TenneT pv 2012-10-01_2012-10-31
# INFO:log:There is already a file: Export_Oktober-2012.csv
# INFO:log:Proceed to download: TenneT pv 2012-11-01_2012-11-30
# INFO:log:There is already a file: Export_November-2012.csv
# INFO:log:Proceed to download: TenneT pv 2012-12-01_2012-12-31
# INFO:log:There is already a file: Export_Dezember-2012.csv
# INFO:log:Proceed to download: TenneT pv 2013-01-01_2013-01-31
# INFO:log:There is already a file: Export_Januar-2013.csv
# INFO:log:Proceed to download: TenneT pv 2013-02-01_2013-02-28
# INFO:log:There is already a file: Export_Februar-2013.csv
# INFO:log:Proceed to download: TenneT pv 2013-03-01_2013-03-31
# INFO:log:There is already a file: Export_Maerz-2013.csv
# INFO:log:Proceed to download: TenneT pv 2013-04-01_2013-04-30
# INFO:log:There is already a file: Export_April-2013.csv
# INFO:log:Proceed to download: TenneT pv 2013-05-01_2013-05-31
# INFO:log:There is already a file: Export_Mai-2013.csv
# INFO:log:Proceed to download: TenneT pv 2013-06-01_2013-06-30
# INFO:log:There is already a file: Export_Juni-2013.csv
# INFO:log:Proceed to download: TenneT pv 2013-07-01_2013-07-31
# INFO:log:There is already a file: Export_Juli-2013.csv
# INFO:log:Proceed to download: TenneT pv 2013-08-01_2013-08-31
# INFO:log:There is already a file: Export_August-2013.csv
# INFO:log:Proceed to download: TenneT pv 2013-09-01_2013-09-30
# INFO:log:There is already a file: Export_September-2013.csv
# INFO:log:Proceed to download: TenneT pv 2013-10-01_2013-10-31
# INFO:log:There is already a file: Export_Oktober-2013.csv
# INFO:log:Proceed to download: TenneT pv 2013-11-01_2013-11-30
# INFO:log:There is already a file: Export_November-2013.csv
# INFO:log:Proceed to download: TenneT pv 2013-12-01_2013-12-31
# INFO:log:There is already a file: Export_Dezember-2013.csv
# INFO:log:Proceed to download: TenneT pv 2014-01-01_2014-01-31
# INFO:log:There is already a file: Export_Januar-2014.csv
# INFO:log:Proceed to download: TenneT pv 2014-02-01_2014-02-28
# INFO:log:There is already a file: Export_Februar-2014.csv
# INFO:log:Proceed to download: TenneT pv 2014-03-01_2014-03-31
# INFO:log:There is already a file: Export_Maerz-2014.csv
# INFO:log:Proceed to download: TenneT pv 2014-04-01_2014-04-30
# INFO:log:There is already a file: Export_April-2014.csv
# INFO:log:Proceed to download: TenneT pv 2014-05-01_2014-05-31
# INFO:log:There is already a file: Export_Mai-2014.csv
# INFO:log:Proceed to download: TenneT pv 2014-06-01_2014-06-30
# INFO:log:There is already a file: Export_Juni-2014.csv
# INFO:log:Proceed to download: TenneT pv 2014-07-01_2014-07-31
# INFO:log:There is already a file: Export_Juli-2014.csv
# INFO:log:Proceed to download: TenneT pv 2014-08-01_2014-08-31
# INFO:log:There is already a file: Export_August-2014.csv
# INFO:log:Proceed to download: TenneT pv 2014-09-01_2014-09-30
# INFO:log:There is already a file: Export_September-2014.csv
# INFO:log:Proceed to download: TenneT pv 2014-10-01_2014-10-31
# INFO:log:There is already a file: Export_Oktober-2014.csv
# INFO:log:Proceed to download: TenneT pv 2014-11-01_2014-11-30
# INFO:log:There is already a file: Export_November-2014.csv
# INFO:log:Proceed to download: TenneT pv 2014-12-01_2014-12-31
# INFO:log:There is already a file: Export_Dezember-2014.csv
# INFO:log:Proceed to download: TenneT pv 2015-01-01_2015-01-31
# INFO:log:There is already a file: Export_Januar-2015.csv
# INFO:log:Proceed to download: TenneT pv 2015-02-01_2015-02-28
# INFO:log:There is already a file: Export_Februar-2015.csv
# INFO:log:There is already a file: mwindeinsp_ist_prognose_2015_04.csv
# INFO:log:Proceed to download: TransnetBW wind 2015-05-01_2015-05-31
# INFO:log:There is already a file: mwindeinsp_ist_prognose_2015_05.csv
# INFO:log:Proceed to download: TransnetBW wind 2015-06-01_2015-06-30
# INFO:log:There is already a file: mwindeinsp_ist_prognose_2015_06.csv
# INFO:log:Proceed to download: TransnetBW wind 2015-07-01_2015-07-31
# INFO:log:There is already a file: mwindeinsp_ist_prognose_2015_07.csv
# INFO:log:Proceed to download: TransnetBW wind 2015-08-01_2015-08-31
# INFO:log:There is already a file: mwindeinsp_ist_prognose_2015_08.csv
# INFO:log:Proceed to download: TransnetBW wind 2015-09-01_2015-09-30
# INFO:log:There is already a file: mwindeinsp_ist_prognose_2015_09.csv
# INFO:log:Proceed to download: TransnetBW wind 2015-10-01_2015-10-31
# INFO:log:There is already a file: mwindeinsp_ist_prognose_2015_10.csv
# INFO:log:Proceed to download: TransnetBW wind 2015-11-01_2015-11-30
# INFO:log:There is already a file: mwindeinsp_ist_prognose_2015_11.csv
# INFO:log:Proceed to download: TransnetBW wind 2015-12-01_2015-12-31
# INFO:log:There is already a file: mwindeinsp_ist_prognose_2015_12.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-01-01_2011-01-31
# INFO:log:There is already a file: msolar_ist_prognose_2011_01.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-02-01_2011-02-28
# INFO:log:There is already a file: msolar_ist_prognose_2011_02.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-03-01_2011-03-31
# INFO:log:There is already a file: msolar_ist_prognose_2011_03.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-04-01_2011-04-30
# INFO:log:There is already a file: msolar_ist_prognose_2011_04.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-05-01_2011-05-31
# INFO:log:There is already a file: msolar_ist_prognose_2011_05.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-06-01_2011-06-30
# INFO:log:There is already a file: msolar_ist_prognose_2011_06.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-07-01_2011-07-31
# INFO:log:There is already a file: msolar_ist_prognose_2011_07.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-08-01_2011-08-31
# INFO:log:There is already a file: msolar_ist_prognose_2011_08.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-09-01_2011-09-30
# INFO:log:There is already a file: msolar_ist_prognose_2011_09.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-10-01_2011-10-31
# INFO:log:There is already a file: msolar_ist_prognose_2011_10.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-11-01_2011-11-30
# INFO:log:There is already a file: msolar_ist_prognose_2011_11.csv
# INFO:log:Proceed to download: TransnetBW pv 2011-12-01_2011-12-31
# INFO:log:There is already a file: msolar_ist_prognose_2011_12.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-01-01_2012-01-31
# INFO:log:There is already a file: msolar_ist_prognose_2012_01.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-02-01_2012-02-29
# INFO:log:There is already a file: msolar_ist_prognose_2012_02.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-03-01_2012-03-31
# INFO:log:There is already a file: msolar_ist_prognose_2012_03.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-04-01_2012-04-30
# INFO:log:There is already a file: msolar_ist_prognose_2012_04.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-05-01_2012-05-31
# INFO:log:There is already a file: msolar_ist_prognose_2012_05.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-06-01_2012-06-30
# INFO:log:There is already a file: msolar_ist_prognose_2012_06.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-07-01_2012-07-31
# INFO:log:There is already a file: msolar_ist_prognose_2012_07.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-08-01_2012-08-31
# INFO:log:There is already a file: msolar_ist_prognose_2012_08.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-09-01_2012-09-30
# INFO:log:There is already a file: msolar_ist_prognose_2012_09.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-10-01_2012-10-31
# INFO:log:There is already a file: msolar_ist_prognose_2012_10.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-11-01_2012-11-30
# INFO:log:There is already a file: msolar_ist_prognose_2012_11.csv
# INFO:log:Proceed to download: TransnetBW pv 2012-12-01_2012-12-31
# INFO:log:There is already a file: msolar_ist_prognose_2012_12.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-01-01_2013-01-31
# INFO:log:There is already a file: msolar_ist_prognose_2013_01.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-02-01_2013-02-28
# INFO:log:There is already a file: msolar_ist_prognose_2013_02.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-03-01_2013-03-31
# INFO:log:There is already a file: msolar_ist_prognose_2013_03.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-04-01_2013-04-30
# INFO:log:There is already a file: msolar_ist_prognose_2013_04.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-05-01_2013-05-31
# INFO:log:There is already a file: msolar_ist_prognose_2013_05.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-06-01_2013-06-30
# INFO:log:There is already a file: msolar_ist_prognose_2013_06.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-07-01_2013-07-31
# INFO:log:There is already a file: msolar_ist_prognose_2013_07.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-08-01_2013-08-31
# INFO:log:There is already a file: msolar_ist_prognose_2013_08.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-09-01_2013-09-30
# INFO:log:There is already a file: msolar_ist_prognose_2013_09.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-10-01_2013-10-31
# INFO:log:There is already a file: msolar_ist_prognose_2013_10.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-11-01_2013-11-30
# INFO:log:There is already a file: msolar_ist_prognose_2013_11.csv
# INFO:log:Proceed to download: TransnetBW pv 2013-12-01_2013-12-31
# INFO:log:There is already a file: msolar_ist_prognose_2013_12.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-01-01_2014-01-31
# INFO:log:There is already a file: msolar_ist_prognose_2014_01.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-02-01_2014-02-28
# INFO:log:There is already a file: msolar_ist_prognose_2014_02.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-03-01_2014-03-31
# INFO:log:There is already a file: msolar_ist_prognose_2014_03.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-04-01_2014-04-30
# INFO:log:There is already a file: msolar_ist_prognose_2014_04.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-05-01_2014-05-31
# INFO:log:There is already a file: msolar_ist_prognose_2014_05.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-06-01_2014-06-30
# INFO:log:There is already a file: msolar_ist_prognose_2014_06.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-07-01_2014-07-31
# INFO:log:There is already a file: msolar_ist_prognose_2014_07.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-08-01_2014-08-31
# INFO:log:There is already a file: msolar_ist_prognose_2014_08.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-09-01_2014-09-30
# INFO:log:There is already a file: msolar_ist_prognose_2014_09.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-10-01_2014-10-31
# INFO:log:There is already a file: msolar_ist_prognose_2014_10.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-11-01_2014-11-30
# INFO:log:There is already a file: msolar_ist_prognose_2014_11.csv
# INFO:log:Proceed to download: TransnetBW pv 2014-12-01_2014-12-31
# INFO:log:There is already a file: msolar_ist_prognose_2014_12.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-01-01_2015-01-31
# INFO:log:There is already a file: msolar_ist_prognose_2015_01.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-02-01_2015-02-28
# INFO:log:There is already a file: msolar_ist_prognose_2015_02.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-03-01_2015-03-31
# INFO:log:There is already a file: msolar_ist_prognose_2015_03.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-04-01_2015-04-30
# INFO:log:There is already a file: msolar_ist_prognose_2015_04.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-05-01_2015-05-31
# INFO:log:There is already a file: msolar_ist_prognose_2015_05.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-06-01_2015-06-30
# INFO:log:There is already a file: msolar_ist_prognose_2015_06.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-07-01_2015-07-31
# INFO:log:There is already a file: msolar_ist_prognose_2015_07.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-08-01_2015-08-31
# INFO:log:There is already a file: msolar_ist_prognose_2015_08.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-09-01_2015-09-30
# INFO:log:There is already a file: msolar_ist_prognose_2015_09.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-10-01_2015-10-31
# INFO:log:There is already a file: msolar_ist_prognose_2015_10.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-11-01_2015-11-30
# INFO:log:There is already a file: msolar_ist_prognose_2015_11.csv
# INFO:log:Proceed to download: TransnetBW pv 2015-12-01_2015-12-31
# INFO:log:There is already a file: msolar_ist_prognose_2015_12.csv
