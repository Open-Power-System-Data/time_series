# %% [markdown]
# # Table of Contents
# * [1. Importing Libraries](#1.-Importing-Libraries)
# * [2. Folder path](#2.-Folder-path)

# %% [markdown]
# # 1. Importing Libraries

# %% [markdown]
# os is used to for the path
#
# pandas is used to read CSVs

# %%
import yaml
import os
import pandas as pd

# %% [markdown]
# # 2. Folder path

# %% [markdown]
# This section creates a folder inside the notebook's directory on the users computer where data are read from.

# %%
downloadpath = 'downloads/'
outputpath = 'output/'
if not os.path.exists(outputpath): os.makedirs(outputpath)

# %%
conf = """
    Fingrid: 
        wind: 
            url_template: http://www.fingrid.fi/en/electricity-market/load-and-generation/windpower/Pages/default.aspx/Excel/TimeSeries.xls?beginDate=20150101&endDate=20151231&variables=H4sIAAAAAAAEAO29B2AcSZYlJi9tynt_SvVK1-B0oQiAYBMk2JBAEOzBiM3mkuwdaUcjKasqgcplVmVdZhZAzO2dvPfee--999577733ujudTif33_8_XGZkAWz2zkrayZ4hgKrIHz9-fB8_Ih7_ZFYX2aTMmyP769nyvDp6_CJb5EfPzn7_N1999fzsJ788--L49_99vv3m8V3-_PHZ8jKv25_MynV-dJ6VTf74rv_RY_7xrKoXWfu6rYvlxdGPj378x3ce3-1_8firZdG-yd-1R198d353_viu_fvxm6It86PvFstZuqqu8jq9yJd5nbVFtUy3uPWdx3el0ePnxTI_qcqqTu96f3y7XZRHP_7k5MnDHeo8_Pjx63l19eWyvH62btd1_jRrMzOWyDdA3aeP_bM5-n8AhQmq0kUBAAA1&cultureId=en-US&dataTimePrecision=5
            bundle: MONTHLY
            start: 2014-11-28
            end: recent
            filetype: xls
    Elia: 
        wind1: 
            url_template: http://publications.elia.be/Publications/Publications/WindForecasting.v2.svc/ExportForecastData?beginDate={u_start:%Y-%m-%d}T23%3A00%3A00.000Z&endDate={u_end:%Y-%m-%d}T23%3A00%3A00.000Z&isOffshore=&isEliaConnected=
            bundle: MONTHLY
            start: 2012-01-01  #the data starts from 2012-19-01
            end: 2012-03-01
            filetype: xls        
        wind2: 
            url_template: http://publications.elia.be/Publications/Publications/WindForecasting.v2.svc/ExportForecastData?beginDate={u_start:%Y-%m-%d}T23%3A00%3A00.000Z&endDate={u_end:%Y-%m-%d}T22%3A00%3A00.000Z&isOffshore=&isEliaConnected=
            bundle: MONTHLY
            start: 2012-03-01
            end: 2012-04-01
            filetype: xls        
        wind3: 
            url_template: http://publications.elia.be/Publications/Publications/WindForecasting.v2.svc/ExportForecastData?beginDate={u_start:%Y-%m-%d}T22%3A00%3A00.000Z&endDate={u_end:%Y-%m-%d}T22%3A00%3A00.000Z&isOffshore=&isEliaConnected=
            bundle: MONTHLY
            start: 2012-04-01
            end: recent
            filetype: xls                
        pv: 
            url_template: http://publications.elia.be/Publications/Publications/SolarForecasting.v3.svc/ExportSolarForecastGraph?dateFrom={u_start:%Y-%m-%d}T23%3A00%3A00.000Z&dateTo={u_end:%Y-%m-%d}T23%3A00%3A00.000Z&sourceId=1
            bundle: MONTHLY
            start: 2012-11-14
            end: recent
            filetype: xls     
    Amprion: 
        wind: 
            url_template: http://preview.amprion.de/applications/applicationfiles/winddaten.php?mode=download&format=csv&start={u_start:%Y.%m.%d}&end={u_end:%Y.%m.%d}
            bundle: complete
            start: 2006-01-03
            end: recent
            filetype: csv 
        pv: 
            url_template: http://amprion.de/applications/applicationfiles/PV_einspeisung.php?mode=download&format=csv&start={u_start:%Y.%m.%d}&end={u_end:%Y.%m.%d}
            bundle: complete
            start: 2010-01-07
            end: recent
            filetype: csv        
#    CEPS: 
#        wind_pv: 
#            url_template: http://www.ceps.cz/_layouts/15/Ceps/_Pages/GraphData.aspx?mode=xlsx&from={u_start:%m.%d.%Y}%2012:00:00%20AM&to={u_end:%m/%d/%Y}%2011:59:59%20PM&hasinterval=False&sol=26&lang=ENG&agr=QH&fnc=SUM&ver=RT&para1=all&
#            bundle: complete
#            start: 2012-01-01
#            end: recent
#            filetype: xlsx      
    TransnetBW: 
        wind: 
            url_template: https://www.transnetbw.de/de/kennzahlen/erneuerbare-energien/windenergie?app=wind&activeTab=csv&selectMonatDownload={month}&view=1&download=true
            bundle: special
            start: 2010-01-01
            end: recent
            filetype: csv       
        pv: 
            url_template: https://www.transnetbw.de/de/kennzahlen/erneuerbare-energien/fotovoltaik?app=solar&activeTab=csv&selectMonatDownload={month}&view=1&download=true
            bundle: special
            start: 2011-01-01
            end: recent
            filetype: csv   
    TenneT: 
        wind: 
            url_template: http://www.tennettso.de/site/de/phpbridge?commandpath=Tatsaechliche_und_prognostizierte_Windenergieeinspeisung%2FmonthDataSheetCsv.php&querystring=monat%3D{u_start:%Y-%m}&contenttype=text%2Fx-csv
            bundle: MONTHLY
            start: 2005-07-13
            end: recent
            filetype: csv
        
        pv: 
            url_template: http://www.tennettso.de/site/de/phpbridge?commandpath=Tatsaechliche_und_prognostizierte_Solarenergieeinspeisung%2FmonthDataSheetCsv.php&sub=total&querystring=monat%3D{u_start:%Y-%m}&contenttype=text%2Fx-csv
            bundle: MONTHLY
            start: 2010-01-01
            end: recent
            filetype: csv   
    50hertz: 
        wind: 
            url_template: http://ws.50hertz.com/web01/api/WindPowerForecast/DownloadFile?fileName={u_start:%Y}.csv&callback=?
            bundle: YEARLY
            start: 2005-01-01
            end: recent
            filetype: csv        
        pv: 
            url_template: http://ws.50hertz.com/web01/api/PhotovoltaicForecast/DownloadFile?fileName={u_start:%Y}.csv&callback=?
            bundle: YEARLY
            start: 2012-01-01
            end: recent
            filetype: csv  
    RTE: 
        wind_pv: 
            url_template: http://clients.rte-france.com/servlets/RealProdServlet?annee={u_start:%Y}
            bundle: YEARLY
            start: 2014-01-01
            end: recent 
            filetype: zip #xls 
    Svenska_Kraftnaet: 
        wind_pv_1: 
            url_template: http://www.svk.se/siteassets/aktorsportalen/statistik/sverigestatistik/n_fot{u_start:%Y}.xls
            bundle: YEARLY
            start: 2002-01-01
            end: 2009-01-01
            filetype: xls        
        wind_pv_2: 
            url_template: http://www.svk.se/siteassets/aktorsportalen/statistik/sverigestatistik/n_fot201001-06.xls
            bundle: YEARLY
            start: 2010-01-01
            end: 2010-01-01
            filetype: xls        
        wind_pv_3: 
            url_template: http://www.svk.se/siteassets/aktorsportalen/statistik/sverigestatistik/n_fot2010-07-12.xls
            bundle: YEARLY
            start: 2010-01-01
            end: 2010-01-01
            filetype: xls       
        wind_pv_4: 
            url_template: http://www.svk.se/siteassets/aktorsportalen/statistik/sverigestatistik/n-fot2011-01-12.xls
            bundle: YEARLY
            start: 2011-01-01
            end: 2011-01-01
            filetype: xls        
        wind_pv_5: 
            url_template: http://www.svk.se/siteassets/aktorsportalen/statistik/sverigestatistik/n_fot{u_start:%Y}-01-12.xls
            bundle: YEARLY
            start: 2012-01-01
            end: 2014-01-01
            filetype: xls    
    OeMag: 
        wind_1: 
            url_template: http://www.oem-ag.at/fileadmin/user_upload/Dokumente/statistik/winderzeugung/winderzeugung_{u_start:%Y}.xls
            bundle: YEARLY
            start: 2003-01-01
            end: 2011-01-01
            filetype: xls        
        wind_2: 
            url_template: http://www.oem-ag.at/fileadmin/user_upload/Dokumente/statistik/winderzeugung/winderzeugung_{u_start:%Y}.xlsx
            bundle: YEARLY
            start: 2012-01-01
            end: recent
            filetype: xls
"""
conf = yaml.load(conf)

# %%
conf = """
TransnetBW: 
        wind: 
            url_template: https://www.transnetbw.de/de/kennzahlen/erneuerbare-energien/windenergie?app=wind&activeTab=csv&selectMonatDownload={month}&view=1&download=true
            bundle: special
            start: 2010-01-01
            end: recent
            filetype: csv       
        pv: 
            url_template: https://www.transnetbw.de/de/kennzahlen/erneuerbare-energien/fotovoltaik?app=solar&activeTab=csv&selectMonatDownload={month}&view=1&download=true
            bundle: special
            start: 2011-01-01
            end: recent
            filetype: csv
"""
conf = yaml.load(conf)

# %%
def readData(filePath, source, tech):
    if os.path.getsize(filePath) < 128:
        print("file is smaller than 128 Byte, which means it's probably empty")
        data = pd.DataFrame() # return empty DataFrame
        return data
    if source = 'TransnetBW':
        data = pd.read_csv(
            filePath,
            decimal=',',
            sep=";",
            parse_dates = {'Timestamp' : ['Datum von', 'Uhrzeit von']},
            index_col = "Timestamp",
            dayfirst=True,
        )

#        data = data.drop('Unnamed: 6', 1)
        data = data.drop('Datum bis', axis=1)
        data = data.drop('Uhrzeit bis', axis=1)
#        data.fillna(0,inplace=True)
    
        forecastCol = source+'_'+tech+'_forecast'
        actualCol = source+'_'+tech+'_forecast'

        data.rename(
            columns={'Prognose (MW)': forecastCol, 'Ist-Wert (MW)': actualCol},
            inplace=True
        )
    
        if 'Datum' in data.columns: 
            del data['Datum']
        if 'Uhrzeit' in data.columns: 
            del data['Uhrzeit']
    elif source = 'TenneT':
        data = pd.read_csv(
            filePath
        
    
    return data

# %%
rng = pd.date_range(start='01/01/2003 00:00', end='18/11/2015 23:45', freq='15 Min')
resultDataSet = pd.DataFrame(index=rng)
resultDataSet.index.names = ['Timestamp']
for source, tech in conf.items():
    for tech, param in tech.items():
        for filename in os.listdir(downloadpath):
            if source in filename:
                if tech in filename:
                    print('reading' filename)
                    try:
                        dataToAdd = readData(downloadpath + filename, source, tech)
                        resultDataSet = resultDataSet.combine_first(dataToAdd)
                    except ValueError:
                        atLeastOneError = 'yes'
                        print('error')
                        
resultDataSet
# Out:
# TransnetBW pv TransnetBW_pv_0[msolar_ist_prognose_2015_11.csv].csv
# TransnetBW pv TransnetBW_pv_10[msolar_ist_prognose_2015_01.csv].csv
# TransnetBW pv TransnetBW_pv_11[msolar_ist_prognose_2015_00.csv].csv
# TransnetBW pv TransnetBW_pv_12[msolar_ist_prognose_2014_11.csv].csv
# TransnetBW pv TransnetBW_pv_13[msolar_ist_prognose_2014_10.csv].csv
# TransnetBW pv TransnetBW_pv_14[msolar_ist_prognose_2014_09.csv].csv
# TransnetBW pv TransnetBW_pv_15[msolar_ist_prognose_2014_08.csv].csv
# TransnetBW pv TransnetBW_pv_16[msolar_ist_prognose_2014_07.csv].csv
# TransnetBW pv TransnetBW_pv_17[msolar_ist_prognose_2014_06.csv].csv
# TransnetBW pv TransnetBW_pv_18[msolar_ist_prognose_2014_05.csv].csv
# TransnetBW pv TransnetBW_pv_19[msolar_ist_prognose_2014_04.csv].csv
# TransnetBW pv TransnetBW_pv_1[msolar_ist_prognose_2015_10.csv].csv
# TransnetBW pv TransnetBW_pv_20[msolar_ist_prognose_2014_03.csv].csv
# TransnetBW pv TransnetBW_pv_21[msolar_ist_prognose_2014_02.csv].csv
# TransnetBW pv TransnetBW_pv_22[msolar_ist_prognose_2014_01.csv].csv
# TransnetBW pv TransnetBW_pv_23[msolar_ist_prognose_2014_00.csv].csv
# TransnetBW pv TransnetBW_pv_24[msolar_ist_prognose_2013_11.csv].csv
# TransnetBW pv TransnetBW_pv_25[msolar_ist_prognose_2013_10.csv].csv
# TransnetBW pv TransnetBW_pv_26[msolar_ist_prognose_2013_09.csv].csv
# TransnetBW pv TransnetBW_pv_27[msolar_ist_prognose_2013_08.csv].csv
# TransnetBW pv TransnetBW_pv_28[msolar_ist_prognose_2013_07.csv].csv
# TransnetBW pv TransnetBW_pv_29[msolar_ist_prognose_2013_06.csv].csv
# TransnetBW pv TransnetBW_pv_2[msolar_ist_prognose_2015_09.csv].csv
# TransnetBW pv TransnetBW_pv_30[msolar_ist_prognose_2013_05.csv].csv
# TransnetBW pv TransnetBW_pv_31[msolar_ist_prognose_2013_04.csv].csv
# TransnetBW pv TransnetBW_pv_32[msolar_ist_prognose_2013_03.csv].csv
# TransnetBW pv TransnetBW_pv_33[msolar_ist_prognose_2013_02.csv].csv
# TransnetBW pv TransnetBW_pv_34[msolar_ist_prognose_2013_01.csv].csv
# TransnetBW pv TransnetBW_pv_35[msolar_ist_prognose_2013_00.csv].csv
# TransnetBW pv TransnetBW_pv_36[msolar_ist_prognose_2012_11.csv].csv
# TransnetBW pv TransnetBW_pv_37[msolar_ist_prognose_2012_10.csv].csv
# TransnetBW pv TransnetBW_pv_38[msolar_ist_prognose_2012_09.csv].csv
# TransnetBW pv TransnetBW_pv_39[msolar_ist_prognose_2012_08.csv].csv
# TransnetBW pv TransnetBW_pv_3[msolar_ist_prognose_2015_08.csv].csv
# TransnetBW pv TransnetBW_pv_40[msolar_ist_prognose_2012_07.csv].csv
# TransnetBW pv TransnetBW_pv_41[msolar_ist_prognose_2012_06.csv].csv
# TransnetBW pv TransnetBW_pv_42[msolar_ist_prognose_2012_05.csv].csv
# TransnetBW pv TransnetBW_pv_43[msolar_ist_prognose_2012_04.csv].csv
# TransnetBW pv TransnetBW_pv_44[msolar_ist_prognose_2012_03.csv].csv
# TransnetBW pv TransnetBW_pv_45[msolar_ist_prognose_2012_02.csv].csv
# TransnetBW pv TransnetBW_pv_46[msolar_ist_prognose_2012_01.csv].csv
# TransnetBW pv TransnetBW_pv_47[msolar_ist_prognose_2012_00.csv].csv
# TransnetBW pv TransnetBW_pv_48[msolar_ist_prognose_2011_11.csv].csv
# TransnetBW pv TransnetBW_pv_49[msolar_ist_prognose_2011_10.csv].csv
# TransnetBW pv TransnetBW_pv_4[msolar_ist_prognose_2015_07.csv].csv
# TransnetBW pv TransnetBW_pv_50[msolar_ist_prognose_2011_09.csv].csv
# TransnetBW pv TransnetBW_pv_51[msolar_ist_prognose_2011_08.csv].csv
# TransnetBW pv TransnetBW_pv_52[msolar_ist_prognose_2011_07.csv].csv
# TransnetBW pv TransnetBW_pv_53[msolar_ist_prognose_2011_06.csv].csv
# TransnetBW pv TransnetBW_pv_54[msolar_ist_prognose_2011_05.csv].csv
# TransnetBW pv TransnetBW_pv_55[msolar_ist_prognose_2011_04.csv].csv
# TransnetBW pv TransnetBW_pv_56[msolar_ist_prognose_2011_03.csv].csv
# TransnetBW pv TransnetBW_pv_57[msolar_ist_prognose_2011_02.csv].csv
# TransnetBW pv TransnetBW_pv_58[msolar_ist_prognose_2011_01.csv].csv
# TransnetBW pv TransnetBW_pv_59[msolar_ist_prognose_2011_00.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_5[msolar_ist_prognose_2015_06.csv].csv
# TransnetBW pv TransnetBW_pv_60[msolar_ist_prognose_2010_11.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_61[msolar_ist_prognose_2010_10.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_62[msolar_ist_prognose_2010_09.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_63[msolar_ist_prognose_2010_08.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_64[msolar_ist_prognose_2010_07.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_65[msolar_ist_prognose_2010_06.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_66[msolar_ist_prognose_2010_05.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_67[msolar_ist_prognose_2010_04.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_68[msolar_ist_prognose_2010_03.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_69[msolar_ist_prognose_2010_02.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_6[msolar_ist_prognose_2015_05.csv].csv
# TransnetBW pv TransnetBW_pv_70[msolar_ist_prognose_2010_01.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_71[msolar_ist_prognose_2010_00.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW pv TransnetBW_pv_7[msolar_ist_prognose_2015_04.csv].csv
# TransnetBW pv TransnetBW_pv_8[msolar_ist_prognose_2015_03.csv].csv
# TransnetBW pv TransnetBW_pv_9[msolar_ist_prognose_2015_02.csv].csv
# TransnetBW wind TransnetBW_wind_0[mwindeinsp_ist_prognose_2015_11.csv].csv
# TransnetBW wind TransnetBW_wind_10[mwindeinsp_ist_prognose_2015_01.csv].csv
# TransnetBW wind TransnetBW_wind_11[mwindeinsp_ist_prognose_2015_00.csv].csv
# TransnetBW wind TransnetBW_wind_12[mwindeinsp_ist_prognose_2014_11.csv].csv
# TransnetBW wind TransnetBW_wind_13[mwindeinsp_ist_prognose_2014_10.csv].csv
# TransnetBW wind TransnetBW_wind_14[mwindeinsp_ist_prognose_2014_09.csv].csv
# TransnetBW wind TransnetBW_wind_15[mwindeinsp_ist_prognose_2014_08.csv].csv
# TransnetBW wind TransnetBW_wind_16[mwindeinsp_ist_prognose_2014_07.csv].csv
# TransnetBW wind TransnetBW_wind_17[mwindeinsp_ist_prognose_2014_06.csv].csv
# TransnetBW wind TransnetBW_wind_18[mwindeinsp_ist_prognose_2014_05.csv].csv
# TransnetBW wind TransnetBW_wind_19[mwindeinsp_ist_prognose_2014_04.csv].csv
# TransnetBW wind TransnetBW_wind_1[mwindeinsp_ist_prognose_2015_10.csv].csv
# TransnetBW wind TransnetBW_wind_20[mwindeinsp_ist_prognose_2014_03.csv].csv
# TransnetBW wind TransnetBW_wind_21[mwindeinsp_ist_prognose_2014_02.csv].csv
# TransnetBW wind TransnetBW_wind_22[mwindeinsp_ist_prognose_2014_01.csv].csv
# TransnetBW wind TransnetBW_wind_23[mwindeinsp_ist_prognose_2014_00.csv].csv
# TransnetBW wind TransnetBW_wind_24[mwindeinsp_ist_prognose_2013_11.csv].csv
# TransnetBW wind TransnetBW_wind_25[mwindeinsp_ist_prognose_2013_10.csv].csv
# TransnetBW wind TransnetBW_wind_26[mwindeinsp_ist_prognose_2013_09.csv].csv
# TransnetBW wind TransnetBW_wind_27[mwindeinsp_ist_prognose_2013_08.csv].csv
# TransnetBW wind TransnetBW_wind_28[mwindeinsp_ist_prognose_2013_07.csv].csv
# TransnetBW wind TransnetBW_wind_29[mwindeinsp_ist_prognose_2013_06.csv].csv
# TransnetBW wind TransnetBW_wind_2[mwindeinsp_ist_prognose_2015_09.csv].csv
# TransnetBW wind TransnetBW_wind_30[mwindeinsp_ist_prognose_2013_05.csv].csv
# TransnetBW wind TransnetBW_wind_31[mwindeinsp_ist_prognose_2013_04.csv].csv
# TransnetBW wind TransnetBW_wind_32[mwindeinsp_ist_prognose_2013_03.csv].csv
# TransnetBW wind TransnetBW_wind_33[mwindeinsp_ist_prognose_2013_02.csv].csv
# TransnetBW wind TransnetBW_wind_34[mwindeinsp_ist_prognose_2013_01.csv].csv
# TransnetBW wind TransnetBW_wind_35[mwindeinsp_ist_prognose_2013_00.csv].csv
# TransnetBW wind TransnetBW_wind_36[mwindeinsp_ist_prognose_2012_11.csv].csv
# TransnetBW wind TransnetBW_wind_37[mwindeinsp_ist_prognose_2012_10.csv].csv
# TransnetBW wind TransnetBW_wind_38[mwindeinsp_ist_prognose_2012_09.csv].csv
# TransnetBW wind TransnetBW_wind_39[mwindeinsp_ist_prognose_2012_08.csv].csv
# TransnetBW wind TransnetBW_wind_3[mwindeinsp_ist_prognose_2015_08.csv].csv
# TransnetBW wind TransnetBW_wind_40[mwindeinsp_ist_prognose_2012_07.csv].csv
# TransnetBW wind TransnetBW_wind_41[mwindeinsp_ist_prognose_2012_06.csv].csv
# TransnetBW wind TransnetBW_wind_42[mwindeinsp_ist_prognose_2012_05.csv].csv
# TransnetBW wind TransnetBW_wind_43[mwindeinsp_ist_prognose_2012_04.csv].csv
# TransnetBW wind TransnetBW_wind_44[mwindeinsp_ist_prognose_2012_03.csv].csv
# TransnetBW wind TransnetBW_wind_45[mwindeinsp_ist_prognose_2012_02.csv].csv
# TransnetBW wind TransnetBW_wind_46[mwindeinsp_ist_prognose_2012_01.csv].csv
# TransnetBW wind TransnetBW_wind_47[mwindeinsp_ist_prognose_2012_00.csv].csv
# TransnetBW wind TransnetBW_wind_48[mwindeinsp_ist_prognose_2011_11.csv].csv
# TransnetBW wind TransnetBW_wind_49[mwindeinsp_ist_prognose_2011_10.csv].csv
# TransnetBW wind TransnetBW_wind_4[mwindeinsp_ist_prognose_2015_07.csv].csv
# TransnetBW wind TransnetBW_wind_50[mwindeinsp_ist_prognose_2011_09.csv].csv
# TransnetBW wind TransnetBW_wind_51[mwindeinsp_ist_prognose_2011_08.csv].csv
# TransnetBW wind TransnetBW_wind_52[mwindeinsp_ist_prognose_2011_07.csv].csv
# TransnetBW wind TransnetBW_wind_53[mwindeinsp_ist_prognose_2011_06.csv].csv
# TransnetBW wind TransnetBW_wind_54[mwindeinsp_ist_prognose_2011_05.csv].csv
# TransnetBW wind TransnetBW_wind_55[mwindeinsp_ist_prognose_2011_04.csv].csv
# TransnetBW wind TransnetBW_wind_56[mwindeinsp_ist_prognose_2011_03.csv].csv
# TransnetBW wind TransnetBW_wind_57[mwindeinsp_ist_prognose_2011_02.csv].csv
# TransnetBW wind TransnetBW_wind_58[mwindeinsp_ist_prognose_2011_01.csv].csv
# TransnetBW wind TransnetBW_wind_59[mwindeinsp_ist_prognose_2011_00.csv].csv
# TransnetBW wind TransnetBW_wind_5[mwindeinsp_ist_prognose_2015_06.csv].csv
# TransnetBW wind TransnetBW_wind_60[mwindeinsp_ist_prognose_2010_11.csv].csv
# TransnetBW wind TransnetBW_wind_61[mwindeinsp_ist_prognose_2010_10.csv].csv
# TransnetBW wind TransnetBW_wind_62[mwindeinsp_ist_prognose_2010_09.csv].csv
# TransnetBW wind TransnetBW_wind_63[mwindeinsp_ist_prognose_2010_08.csv].csv
# TransnetBW wind TransnetBW_wind_64[mwindeinsp_ist_prognose_2010_07.csv].csv
# TransnetBW wind TransnetBW_wind_65[mwindeinsp_ist_prognose_2010_06.csv].csv
# TransnetBW wind TransnetBW_wind_66[mwindeinsp_ist_prognose_2010_05.csv].csv
# TransnetBW wind TransnetBW_wind_67[mwindeinsp_ist_prognose_2010_04.csv].csv
# TransnetBW wind TransnetBW_wind_68[mwindeinsp_ist_prognose_2010_03.csv].csv
# TransnetBW wind TransnetBW_wind_69[mwindeinsp_ist_prognose_2010_02.csv].csv
# TransnetBW wind TransnetBW_wind_6[mwindeinsp_ist_prognose_2015_05.csv].csv
# TransnetBW wind TransnetBW_wind_70[mwindeinsp_ist_prognose_2010_01.csv].csv
# TransnetBW wind TransnetBW_wind_71[mwindeinsp_ist_prognose_2010_00.csv].csv
# file is smaller than 128 Byte, which means it's probably empty
# TransnetBW wind TransnetBW_wind_7[mwindeinsp_ist_prognose_2015_04.csv].csv
# TransnetBW wind TransnetBW_wind_8[mwindeinsp_ist_prognose_2015_03.csv].csv
# TransnetBW wind TransnetBW_wind_9[mwindeinsp_ist_prognose_2015_02.csv].csv
#                      actual_TransnetBW_pv  actual_TransnetBW_wind  \
# Timestamp
# 2006-01-01 00:00:00                   NaN                     NaN
# 2006-01-01 00:15:00                   NaN                     NaN
# 2006-01-01 00:30:00                   NaN                     NaN
# 2006-01-01 00:45:00                   NaN                     NaN
# 2006-01-01 01:00:00                   NaN                     NaN
# 2006-01-01 01:15:00                   NaN                     NaN
# 2006-01-01 01:30:00                   NaN                     NaN
# 2006-01-01 01:45:00                   NaN                     NaN
# 2006-01-01 02:00:00                   NaN                     NaN
# 2006-01-01 02:15:00                   NaN                     NaN
# 2006-01-01 02:30:00                   NaN                     NaN
# 2006-01-01 02:45:00                   NaN                     NaN
# 2006-01-01 03:00:00                   NaN                     NaN
# 2006-01-01 03:15:00                   NaN                     NaN
# 2006-01-01 03:30:00                   NaN                     NaN
# 2006-01-01 03:45:00                   NaN                     NaN
# 2006-01-01 04:00:00                   NaN                     NaN
# 2006-01-01 04:15:00                   NaN                     NaN
# 2006-01-01 04:30:00                   NaN                     NaN
# 2006-01-01 04:45:00                   NaN                     NaN
# 2006-01-01 05:00:00                   NaN                     NaN
# 2006-01-01 05:15:00                   NaN                     NaN
# 2006-01-01 05:30:00                   NaN                     NaN
# 2006-01-01 05:45:00                   NaN                     NaN
# 2006-01-01 06:00:00                   NaN                     NaN
# 2006-01-01 06:15:00                   NaN                     NaN
# 2006-01-01 06:30:00                   NaN                     NaN
# 2006-01-01 06:45:00                   NaN                     NaN
# 2006-01-01 07:00:00                   NaN                     NaN
# 2006-01-01 07:15:00                   NaN                     NaN
# ...                                   ...                     ...
# 2015-11-18 16:30:00                     0                       0
# 2015-11-18 16:45:00                     0                       0
# 2015-11-18 17:00:00                     0                       0
# 2015-11-18 17:15:00                     0                       0
# 2015-11-18 17:30:00                     0                       0
# 2015-11-18 17:45:00                     0                       0
# 2015-11-18 18:00:00                     0                       0
# 2015-11-18 18:15:00                     0                       0
# 2015-11-18 18:30:00                     0                       0
# 2015-11-18 18:45:00                     0                       0
# 2015-11-18 19:00:00                     0                       0
# 2015-11-18 19:15:00                     0                       0
# 2015-11-18 19:30:00                     0                       0
# 2015-11-18 19:45:00                     0                       0
# 2015-11-18 20:00:00                     0                       0
# 2015-11-18 20:15:00                     0                       0
# 2015-11-18 20:30:00                     0                       0
# 2015-11-18 20:45:00                     0                       0
# 2015-11-18 21:00:00                     0                       0
# 2015-11-18 21:15:00                     0                       0
# 2015-11-18 21:30:00                     0                       0
# 2015-11-18 21:45:00                     0                       0
# 2015-11-18 22:00:00                     0                       0
# 2015-11-18 22:15:00                     0                       0
# 2015-11-18 22:30:00                     0                       0
# 2015-11-18 22:45:00                     0                       0
# 2015-11-18 23:00:00                     0                       0
# 2015-11-18 23:15:00                     0                       0
# 2015-11-18 23:30:00                     0                       0
# 2015-11-18 23:45:00                     0                       0
#
#                      forecast_TransnetBW_pv  forecast_TransnetBW_wind
# Timestamp
# 2006-01-01 00:00:00                     NaN                       NaN
# 2006-01-01 00:15:00                     NaN                       NaN
# 2006-01-01 00:30:00                     NaN                       NaN
# 2006-01-01 00:45:00                     NaN                       NaN
# 2006-01-01 01:00:00                     NaN                       NaN
# 2006-01-01 01:15:00                     NaN                       NaN
# 2006-01-01 01:30:00                     NaN                       NaN
# 2006-01-01 01:45:00                     NaN                       NaN
# 2006-01-01 02:00:00                     NaN                       NaN
# 2006-01-01 02:15:00                     NaN                       NaN
# 2006-01-01 02:30:00                     NaN                       NaN
# 2006-01-01 02:45:00                     NaN                       NaN
# 2006-01-01 03:00:00                     NaN                       NaN
# 2006-01-01 03:15:00                     NaN                       NaN
# 2006-01-01 03:30:00                     NaN                       NaN
# 2006-01-01 03:45:00                     NaN                       NaN
# 2006-01-01 04:00:00                     NaN                       NaN
# 2006-01-01 04:15:00                     NaN                       NaN
# 2006-01-01 04:30:00                     NaN                       NaN
# 2006-01-01 04:45:00                     NaN                       NaN
# 2006-01-01 05:00:00                     NaN                       NaN
# 2006-01-01 05:15:00                     NaN                       NaN
# 2006-01-01 05:30:00                     NaN                       NaN
# 2006-01-01 05:45:00                     NaN                       NaN
# 2006-01-01 06:00:00                     NaN                       NaN
# 2006-01-01 06:15:00                     NaN                       NaN
# 2006-01-01 06:30:00                     NaN                       NaN
# 2006-01-01 06:45:00                     NaN                       NaN
# 2006-01-01 07:00:00                     NaN                       NaN
# 2006-01-01 07:15:00                     NaN                       NaN
# ...                                     ...                       ...
# 2015-11-18 16:30:00                      16                       412
# 2015-11-18 16:45:00                       5                       402
# 2015-11-18 17:00:00                       0                       394
# 2015-11-18 17:15:00                       0                       387
# 2015-11-18 17:30:00                       0                       380
# 2015-11-18 17:45:00                       0                       373
# 2015-11-18 18:00:00                       0                       372
# 2015-11-18 18:15:00                       0                       377
# 2015-11-18 18:30:00                       0                       381
# 2015-11-18 18:45:00                       0                       386
# 2015-11-18 19:00:00                       0                       391
# 2015-11-18 19:15:00                       0                       396
# 2015-11-18 19:30:00                       0                       401
# 2015-11-18 19:45:00                       0                       406
# 2015-11-18 20:00:00                       0                       413
# 2015-11-18 20:15:00                       0                       421
# 2015-11-18 20:30:00                       0                       429
# 2015-11-18 20:45:00                       0                       436
# 2015-11-18 21:00:00                       0                       447
# 2015-11-18 21:15:00                       0                       460
# 2015-11-18 21:30:00                       0                       474
# 2015-11-18 21:45:00                       0                       487
# 2015-11-18 22:00:00                       0                       498
# 2015-11-18 22:15:00                       0                       507
# 2015-11-18 22:30:00                       0                       516
# 2015-11-18 22:45:00                       0                       525
# 2015-11-18 23:00:00                       0                       533
# 2015-11-18 23:15:00                       0                       542
# 2015-11-18 23:30:00                       0                       550
# 2015-11-18 23:45:00                       0                       558
#
# [346594 rows x 4 columns]

# %%
resultDataSet.to_csv(outputpath+"Output1.csv", sep=';')

# %% [markdown]
# ### to do
#
# periodindex ?
#
# Iso Format:
#
# Proposal: several time variables
# • ISO 8601 UTC
# YYYY-MM-DDThh:mm:ssZ
# • ISO 8601 local time (difference to UTC)
# YYYY-MM-DDThh:mm:ss+hh:mm
# • a set of time variables: year,
# month_year, day_year, hour_day,
# hour_year, weekday, peak / off-peak
